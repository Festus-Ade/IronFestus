# %% [markdown]
# ### Wednesday Task

# %%
billboards = pd.read_csv("billboards.csv")

# %%
billboards
# Out:
#     Unnamed: 0               song                                   artist
# 0            0          Kill Bill                                      SZA
# 1            1         Last Night                            Morgan Wallen
# 2            2            Flowers                              Miley Cyrus
# 3            3     Princess Diana                  Ice Spice & Nicki Minaj
# 4            4    Ella Baila Sola              Eslabon Armado X Peso Pluma
# ..         ...                ...                                      ...
# 95          95        Memory Lane                             Old Dominion
# 96          96         Love Again                            The Kid LAROI
# 97          97         '98 Braves                            Morgan Wallen
# 98          98          Di Que Si  Grupo Marca Registrada X Grupo Frontera
# 99          99  It Matters To Her                          Scotty McCreery
#
# [100 rows x 3 columns]

# %%
import config
import pandas as pd
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
from matplotlib import pyplot
from sklearn.metrics import silhouette_score


#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return results

# %%
#Alternative rock pop rock

tracks=get_playlist_tracks('spotify','08TLdfhhMmY9el7Tj1Faql')
tracks
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/08TLdfhhMmY9el7Tj1Faql/tracks?offset=100&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2022-08-28T09:07:02Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/cytpxbcy0o2tn4nw3789snhde'},
#     'href': 'https://api.spotify.com/v1/users/cytpxbcy0o2tn4nw3789snhde',
#     'id': 'cytpxbcy0o2tn4nw3789snhde',
#     'type': 'user',
#     'uri': 'spotify:user:cytpxbcy0o2tn4nw3789snhde'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#        'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#        'id': '4gzpq5DPGxSnKTe4SA8HAU',
#        'name': 'Coldplay',
#        'type': 'artist',
#        'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
# ...

# %%
tracks["items"]
# Out:
# [{'added_at': '2022-08-28T09:07:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/cytpxbcy0o2tn4nw3789snhde'},
#    'href': 'https://api.spotify.com/v1/users/cytpxbcy0o2tn4nw3789snhde',
#    'id': 'cytpxbcy0o2tn4nw3789snhde',
#    'type': 'user',
#    'uri': 'spotify:user:cytpxbcy0o2tn4nw3789snhde'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#       'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#       'id': '4gzpq5DPGxSnKTe4SA8HAU',
#       'name': 'Coldplay',
#       'type': 'artist',
#       'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2G4AUqfwxcV1UdQjm2ouYr'},
#     'href': 'https://api.spotify.com/v1/albums/2G4AUqfwxcV1UdQjm2ouYr',
# ...

# %% [markdown]
# ### Extracting the songs ids from playlist

# %%
list_of_audio_features.append(sp.audio_features(tracks['items'][0]["track"]["id"]))

# %%
sp.audio_features(tracks['items'][0]["track"]["id"])
# Out:
# [{'danceability': 0.516,
#   'energy': 0.572,
#   'key': 8,
#   'loudness': -9.037,
#   'mode': 1,
#   'speechiness': 0.0291,
#   'acousticness': 0.00715,
#   'instrumentalness': 0.254,
#   'liveness': 0.139,
#   'valence': 0.351,
#   'tempo': 160.023,
#   'type': 'audio_features',
#   'id': '22uzF19LxQW87kOVkR79Fq',
#   'uri': 'spotify:track:22uzF19LxQW87kOVkR79Fq',
#   'track_href': 'https://api.spotify.com/v1/tracks/22uzF19LxQW87kOVkR79Fq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22uzF19LxQW87kOVkR79Fq',
#   'duration_ms': 234413,
#   'time_signature': 4}]

# %%
tracks['items'][58]["track"]["id"]
# Out:
# '4fzyvSu73BhGvi96p2zwjL'

# %%
list_of_audio_features=[]
for item in range(0,59):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks['items'][item]["track"]["id"])[0])

# %%
list_of_audio_features
# Out:
# [{'danceability': 0.516,
#   'energy': 0.572,
#   'key': 8,
#   'loudness': -9.037,
#   'mode': 1,
#   'speechiness': 0.0291,
#   'acousticness': 0.00715,
#   'instrumentalness': 0.254,
#   'liveness': 0.139,
#   'valence': 0.351,
#   'tempo': 160.023,
#   'type': 'audio_features',
#   'id': '22uzF19LxQW87kOVkR79Fq',
#   'uri': 'spotify:track:22uzF19LxQW87kOVkR79Fq',
#   'track_href': 'https://api.spotify.com/v1/tracks/22uzF19LxQW87kOVkR79Fq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22uzF19LxQW87kOVkR79Fq',
#   'duration_ms': 234413,
#   'time_signature': 4},
#  {'danceability': 0.565,
#   'energy': 0.546,
#   'key': 11,
#   'loudness': -7.496,
#   'mode': 0,
#   'speechiness': 0.0314,
#   'acousticness': 0.189,
#   'instrumentalness': 0.0015,
#   'liveness': 0.17,
#   'valence': 0.195,
#   'tempo': 139.757,
#   'type': 'audio_features',
#   'id': '0R8P9KfGJCDULmlEoBagcO',
#   'uri': 'spotify:track:0R8P9KfGJCDULmlEoBagcO',
# ...

# %%
df1=pd.DataFrame(list_of_audio_features)    
df1=df1[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df1
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.516   0.572    -9.037       0.0291      0.007150
# 1          0.565   0.546    -7.496       0.0314      0.189000
# 2          0.566   0.459    -9.488       0.0289      0.327000
# 3          0.537   0.128   -28.388       0.0511      0.996000
# 4          0.433   0.288   -10.801       0.0296      0.535000
# 5          0.795   0.437    -8.127       0.0830      0.013700
# 6          0.641   0.244   -11.051       0.0301      0.235000
# 7          0.469   0.481    -9.130       0.0255      0.041000
# 8          0.532   0.433    -9.423       0.0278      0.094200
# 9          0.285   0.279   -11.992       0.0292      0.401000
# 10         0.595   0.638    -7.941       0.0307      0.104000
# 11         0.518   0.620    -9.668       0.0273      0.059600
# 12         0.330   0.580    -7.875       0.0374      0.061400
# 13         0.595   0.315   -11.456       0.0296      0.427000
# ...

# %%
len(df1.columns)
# Out:
# 11

# %%
### Second playlist

# %%
tracks2=get_playlist_tracks('spotify','5UCTxzSLARB6b1Msxooky8')
tracks2
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/5UCTxzSLARB6b1Msxooky8/tracks?offset=300&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2020-06-20T04:48:47Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/vigorousity'},
#     'href': 'https://api.spotify.com/v1/users/vigorousity',
#     'id': 'vigorousity',
#     'type': 'user',
#     'uri': 'spotify:user:vigorousity'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6B5c4sch27tWHAGdarpPaW'},
#        'href': 'https://api.spotify.com/v1/artists/6B5c4sch27tWHAGdarpPaW',
#        'id': '6B5c4sch27tWHAGdarpPaW',
#        'name': 'Seether',
#        'type': 'artist',
#        'uri': 'spotify:artist:6B5c4sch27tWHAGdarpPaW'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/59Tni3gA1OczshFWTMxmbo'},
# ...

# %%
len(tracks2["items"])
# Out:
# 56

# %%
list_of_audio_features.append(sp.audio_features(tracks2['items'][0]["track"]["id"]))

# %%
sp.audio_features(tracks2['items'][0]["track"]["id"])
# Out:
# [{'danceability': 0.469,
#   'energy': 0.943,
#   'key': 2,
#   'loudness': -4.196,
#   'mode': 1,
#   'speechiness': 0.102,
#   'acousticness': 6.07e-05,
#   'instrumentalness': 0.00547,
#   'liveness': 0.0717,
#   'valence': 0.358,
#   'tempo': 134.031,
#   'type': 'audio_features',
#   'id': '46eHxWRKmtYhUHPDRgclt6',
#   'uri': 'spotify:track:46eHxWRKmtYhUHPDRgclt6',
#   'track_href': 'https://api.spotify.com/v1/tracks/46eHxWRKmtYhUHPDRgclt6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/46eHxWRKmtYhUHPDRgclt6',
#   'duration_ms': 296973,
#   'time_signature': 4}]

# %%
list_of_audio_features=[]
for item in range(0,50):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks2['items'][item]["track"]["id"])[0])

# %%
list_of_audio_features
# Out:
# [{'danceability': 0.469,
#   'energy': 0.943,
#   'key': 2,
#   'loudness': -4.196,
#   'mode': 1,
#   'speechiness': 0.102,
#   'acousticness': 6.07e-05,
#   'instrumentalness': 0.00547,
#   'liveness': 0.0717,
#   'valence': 0.358,
#   'tempo': 134.031,
#   'type': 'audio_features',
#   'id': '46eHxWRKmtYhUHPDRgclt6',
#   'uri': 'spotify:track:46eHxWRKmtYhUHPDRgclt6',
#   'track_href': 'https://api.spotify.com/v1/tracks/46eHxWRKmtYhUHPDRgclt6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/46eHxWRKmtYhUHPDRgclt6',
#   'duration_ms': 296973,
#   'time_signature': 4},
#  {'danceability': 0.373,
#   'energy': 0.939,
#   'key': 1,
#   'loudness': -3.153,
#   'mode': 0,
#   'speechiness': 0.0603,
#   'acousticness': 0.00677,
#   'instrumentalness': 0,
#   'liveness': 0.137,
#   'valence': 0.429,
#   'tempo': 176.022,
#   'type': 'audio_features',
#   'id': '1OG0QQa2zZe4QeFwVhCiiA',
#   'uri': 'spotify:track:1OG0QQa2zZe4QeFwVhCiiA',
# ...

# %%
df2=pd.DataFrame(list_of_audio_features)    
df2=df2[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df2
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.469   0.943    -4.196       0.1020      0.000061
# 1          0.373   0.939    -3.153       0.0603      0.006770
# 2          0.402   0.970    -4.538       0.0668      0.000013
# 3          0.461   0.921    -3.570       0.0461      0.000067
# 4          0.450   0.921    -3.476       0.0538      0.046700
# 5          0.185   0.948    -3.892       0.1470      0.010400
# 6          0.535   0.951    -3.324       0.1800      0.007770
# 7          0.509   0.938    -3.883       0.0715      0.000644
# 8          0.274   0.792    -4.388       0.0413      0.008330
# 9          0.483   0.941    -3.598       0.0575      0.000526
# 10         0.623   0.930    -5.285       0.0324      0.014100
# 11         0.376   0.950    -4.067       0.0641      0.000210
# 12         0.345   0.929    -4.469       0.1420      0.000150
# 13         0.370   0.889    -4.750       0.0611      0.001590
# ...

# %%
concat = pd.concat([df1, df2], axis=0)

concat
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.516   0.572    -9.037       0.0291      0.007150
# 1          0.565   0.546    -7.496       0.0314      0.189000
# 2          0.566   0.459    -9.488       0.0289      0.327000
# 3          0.537   0.128   -28.388       0.0511      0.996000
# 4          0.433   0.288   -10.801       0.0296      0.535000
# ..           ...     ...       ...          ...           ...
# 45         0.490   0.852    -7.192       0.0502      0.037600
# 46         0.815   0.605    -9.118       0.0368      0.033000
# 47         0.661   0.978    -3.064       0.1070      0.024700
# 48         0.550   0.874    -4.046       0.0321      0.000436
# 49         0.421   0.858    -4.535       0.0963      0.013400
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.254000    0.1390    0.351  160.023  22uzF19LxQW87kOVkR79Fq
# ...

# %%
len(concat.columns)
# Out:
# 11

# %%
#df.to_csv('my_data.csv', index=False)

# %%
#def playlist_tracks():

# %%
### third playlist

# %%
tracks3=get_playlist_tracks('spotify','4ap40qPoig2h0LeOrybYNi')
tracks3
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/4ap40qPoig2h0LeOrybYNi/tracks?offset=200&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2018-12-30T03:44:08Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/scarcasticsia'},
#     'href': 'https://api.spotify.com/v1/users/scarcasticsia',
#     'id': 'scarcasticsia',
#     'type': 'user',
#     'uri': 'spotify:user:scarcasticsia'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'album',
#      'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jOstUTkEu2JkjvRdBA5Gu'},
#        'href': 'https://api.spotify.com/v1/artists/3jOstUTkEu2JkjvRdBA5Gu',
#        'id': '3jOstUTkEu2JkjvRdBA5Gu',
#        'name': 'Weezer',
#        'type': 'artist',
#        'uri': 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'}],
# ...

# %%
len(tracks3["items"])
# Out:
# 42

# %%
list_of_audio_features.append(sp.audio_features(tracks3['items'][0]["track"]["id"]))

# %%
sp.audio_features(tracks3['items'][0]["track"]["id"])
# Out:
# [{'danceability': 0.651,
#   'energy': 0.804,
#   'key': 4,
#   'loudness': -6.264,
#   'mode': 0,
#   'speechiness': 0.0283,
#   'acousticness': 0.0095,
#   'instrumentalness': 0.00386,
#   'liveness': 0.182,
#   'valence': 0.713,
#   'tempo': 114.635,
#   'type': 'audio_features',
#   'id': '0AxdJGlXJjEUsNONDuT2pe',
#   'uri': 'spotify:track:0AxdJGlXJjEUsNONDuT2pe',
#   'track_href': 'https://api.spotify.com/v1/tracks/0AxdJGlXJjEUsNONDuT2pe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0AxdJGlXJjEUsNONDuT2pe',
#   'duration_ms': 200067,
#   'time_signature': 4}]

# %%
list_of_audio_features=[]
for item in range(0,42):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks3['items'][item]["track"]["id"])[0])

# %%
list_of_audio_features
# Out:
# [{'danceability': 0.651,
#   'energy': 0.804,
#   'key': 4,
#   'loudness': -6.264,
#   'mode': 0,
#   'speechiness': 0.0283,
#   'acousticness': 0.0095,
#   'instrumentalness': 0.00386,
#   'liveness': 0.182,
#   'valence': 0.713,
#   'tempo': 114.635,
#   'type': 'audio_features',
#   'id': '0AxdJGlXJjEUsNONDuT2pe',
#   'uri': 'spotify:track:0AxdJGlXJjEUsNONDuT2pe',
#   'track_href': 'https://api.spotify.com/v1/tracks/0AxdJGlXJjEUsNONDuT2pe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0AxdJGlXJjEUsNONDuT2pe',
#   'duration_ms': 200067,
#   'time_signature': 4},
#  {'danceability': 0.716,
#   'energy': 0.818,
#   'key': 7,
#   'loudness': -7.456,
#   'mode': 1,
#   'speechiness': 0.0256,
#   'acousticness': 0.154,
#   'instrumentalness': 0.000806,
#   'liveness': 0.236,
#   'valence': 0.817,
#   'tempo': 103.668,
#   'type': 'audio_features',
#   'id': '75CgD6l7K4qMzZrn4CbZqz',
#   'uri': 'spotify:track:75CgD6l7K4qMzZrn4CbZqz',
# ...

# %%
df3=pd.DataFrame(list_of_audio_features)    
df3=df3[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df3
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.651   0.804    -6.264       0.0283      0.009500
# 1          0.716   0.818    -7.456       0.0256      0.154000
# 2          0.540   0.429   -11.822       0.0285      0.000202
# 3          0.652   0.669    -7.663       0.0370      0.063900
# 4          0.628   0.871    -6.440       0.0363      0.007700
# 5          0.656   0.932    -3.405       0.0708      0.003470
# 6          0.820   0.452    -9.796       0.0348      0.543000
# 7          0.578   0.817    -6.542       0.0363      0.183000
# 8          0.547   0.707    -8.740       0.0338      0.000081
# 9          0.561   0.593    -9.362       0.0264      0.003270
# 10         0.475   0.432    -7.844       0.0302      0.183000
# 11         0.352   0.912    -4.253       0.0725      0.001970
# 12         0.681   0.174    -8.745       0.0315      0.837000
# 13         0.439   0.153    -8.950       0.0479      0.874000
# ...

# %%
concat = pd.concat([df1, df2, df3], axis=0)

concat
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.516   0.572    -9.037       0.0291      0.007150
# 1          0.565   0.546    -7.496       0.0314      0.189000
# 2          0.566   0.459    -9.488       0.0289      0.327000
# 3          0.537   0.128   -28.388       0.0511      0.996000
# 4          0.433   0.288   -10.801       0.0296      0.535000
# ..           ...     ...       ...          ...           ...
# 37         0.495   0.613    -9.463       0.0239      0.348000
# 38         0.621   0.901    -5.396       0.0302      0.170000
# 39         0.651   0.804    -6.264       0.0283      0.009500
# 40         0.695   0.876    -4.262       0.0553      0.000996
# 41         0.352   0.911    -5.230       0.0747      0.001210
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.254000    0.1390    0.351  160.023  22uzF19LxQW87kOVkR79Fq
# ...

# %%
#### third playlist
# rnb

# %%
tracks4=get_playlist_tracks('spotify','6GcssIqNfMVPhxQRlkc8hJ')
tracks4
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/6GcssIqNfMVPhxQRlkc8hJ/tracks?offset=400&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2019-03-13T13:56:10Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/312bh3qcnw5lufy2ijsm2gys3q5a'},
#     'href': 'https://api.spotify.com/v1/users/312bh3qcnw5lufy2ijsm2gys3q5a',
#     'id': '312bh3qcnw5lufy2ijsm2gys3q5a',
#     'type': 'user',
#     'uri': 'spotify:user:312bh3qcnw5lufy2ijsm2gys3q5a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'single',
#      'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27FGXRNruFoOdf1vP8dqcH'},
#        'href': 'https://api.spotify.com/v1/artists/27FGXRNruFoOdf1vP8dqcH',
#        'id': '27FGXRNruFoOdf1vP8dqcH',
#        'name': 'Cassie',
#        'type': 'artist',
#        'uri': 'spotify:artist:27FGXRNruFoOdf1vP8dqcH'}],
# ...

# %%
len(tracks4["items"])
# Out:
# 70

# %%
list_of_audio_features.append(sp.audio_features(tracks4['items'][0]["track"]["id"]))

# %%
sp.audio_features(tracks4['items'][0]["track"]["id"])
# Out:
# [{'danceability': 0.691,
#   'energy': 0.875,
#   'key': 6,
#   'loudness': -4.837,
#   'mode': 0,
#   'speechiness': 0.124,
#   'acousticness': 0.0428,
#   'instrumentalness': 0,
#   'liveness': 0.144,
#   'valence': 0.534,
#   'tempo': 111.345,
#   'type': 'audio_features',
#   'id': '598UYsme1D5MkXHDXf4j6h',
#   'uri': 'spotify:track:598UYsme1D5MkXHDXf4j6h',
#   'track_href': 'https://api.spotify.com/v1/tracks/598UYsme1D5MkXHDXf4j6h',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/598UYsme1D5MkXHDXf4j6h',
#   'duration_ms': 257502,
#   'time_signature': 4}]

# %%
list_of_audio_features=[]
for item in range(0,42):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks4['items'][item]["track"]["id"])[0])

# %%
df4=pd.DataFrame(list_of_audio_features)    
df4=df4[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df4
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.691   0.875    -4.837       0.1240       0.04280
# 1          0.769   0.770    -4.658       0.3270       0.08630
# 2          0.781   0.807    -5.574       0.2610       0.05240
# 3          0.901   0.371    -5.492       0.1080       0.04840
# 4          0.621   0.525    -7.873       0.0391       0.31400
# 5          0.622   0.711    -6.618       0.0542       0.04570
# 6          0.727   0.649    -5.356       0.0338       0.66100
# 7          0.842   0.460    -8.131       0.0648       0.02740
# 8          0.686   0.599    -4.487       0.0512       0.31100
# 9          0.647   0.478    -8.837       0.0782       0.54700
# 10         0.846   0.482    -6.721       0.1290       0.02460
# 11         0.740   0.945    -4.442       0.0889       0.12300
# 12         0.513   0.606    -5.757       0.1480       0.05310
# 13         0.719   0.535    -7.379       0.0370       0.02670
# ...

# %%
concat = pd.concat([df1, df2, df3, df4], axis=0)

# %%
#### fourth playlist
# rnb

# %%
tracks5=get_playlist_tracks('spotify','1Os7m597ihMJ4xTohCkZIz')
tracks5
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/1Os7m597ihMJ4xTohCkZIz/tracks?offset=100&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2023-03-13T21:38:59Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/savz8vts72hqdy7von3mqc29g'},
#     'href': 'https://api.spotify.com/v1/users/savz8vts72hqdy7von3mqc29g',
#     'id': 'savz8vts72hqdy7von3mqc29g',
#     'type': 'user',
#     'uri': 'spotify:user:savz8vts72hqdy7von3mqc29g'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'single',
#      'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#        'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#        'id': '7tYKF4w9nC0nq9CsPZTHyP',
#        'name': 'SZA',
#        'type': 'artist',
#        'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
# ...

# %%
len(tracks5["items"])
# Out:
# 80

# %%
list_of_audio_features.append(sp.audio_features(tracks5['items'][0]["track"]["id"]))

# %%
sp.audio_features(tracks5['items'][0]["track"]["id"])
# Out:
# [{'danceability': 0.824,
#   'energy': 0.453,
#   'key': 3,
#   'loudness': -9.604,
#   'mode': 0,
#   'speechiness': 0.0968,
#   'acousticness': 0.146,
#   'instrumentalness': 0.0273,
#   'liveness': 0.0896,
#   'valence': 0.552,
#   'tempo': 119.959,
#   'type': 'audio_features',
#   'id': '34ZAzO78a5DAVNrYIGWcPm',
#   'uri': 'spotify:track:34ZAzO78a5DAVNrYIGWcPm',
#   'track_href': 'https://api.spotify.com/v1/tracks/34ZAzO78a5DAVNrYIGWcPm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/34ZAzO78a5DAVNrYIGWcPm',
#   'duration_ms': 181831,
#   'time_signature': 4}]

# %%
list_of_audio_features=[]
for item in range(0,42):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks5['items'][item]["track"]["id"])[0])

# %%
df5=pd.DataFrame(list_of_audio_features)    
df5=df5[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

# %%
concat = pd.concat([df1, df2, df3, df4, df5], axis=0)

concat
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.516   0.572    -9.037       0.0291       0.00715
# 1          0.565   0.546    -7.496       0.0314       0.18900
# 2          0.566   0.459    -9.488       0.0289       0.32700
# 3          0.537   0.128   -28.388       0.0511       0.99600
# 4          0.433   0.288   -10.801       0.0296       0.53500
# ..           ...     ...       ...          ...           ...
# 37         0.656   0.432    -9.481       0.2170       0.44300
# 38         0.678   0.355    -7.757       0.0627       0.75900
# 39         0.701   0.692    -4.670       0.1150       0.69900
# 40         0.581   0.512    -8.126       0.2850       0.14800
# 41         0.649   0.347    -7.670       0.4040       0.48500
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.254000     0.139   0.3510  160.023  22uzF19LxQW87kOVkR79Fq
# ...

# %%
def get_playlist_audio_features(username, playlist_id):

    results = sp.user_playlist_tracks(username, playlist_id, market="GB")a
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])


    list_of_audio_features = []
    for track in tracks:
        audio_features = sp.audio_features(track['track']['id'])
        if audio_features is not None:
            list_of_audio_features.append(audio_features[0])


    df = pd.DataFrame(list_of_audio_features)
    df = df[["danceability", "energy", "loudness", "speechiness", "acousticness", 
             "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]

    return df
# Out:
#   File "/var/folders/v6/6m2bpdm12rn2zbd3w9c2c7q00000gn/T/ipykernel_12025/1491550964.py", line 3
#     results = sp.user_playlist_tracks(username, playlist_id, market="GB")a
#                                                                          ^
# SyntaxError: invalid syntax

# %%
df6 = get_playlist_audio_features('spotify', '37i9dQZF1EQoqCH7BwIYb7')

# %%
df7 = get_playlist_audio_features('spotify', '13YDWMOgGy2xUwhEDxc9NE')

# %%
df8 = get_playlist_audio_features('spotify', '5ARwZpSw3P24TXsQXVr54a')

# %%
df9 = get_playlist_audio_features('spotify', '37i9dQZF1DX04mASjTsvf0')

# %%
df10 = get_playlist_audio_features('spotify', '1RJflr2ZNVPMMVAMMdBR5l')

# %%
df11 = get_playlist_audio_features('spotify', '0dns65urSNvprbd6UX2HvG')

# %%
df12 = get_playlist_audio_features('spotify', '0dns65urSNvprbd6UX2HvG')

# %%
df13 = get_playlist_audio_features('spotify', '4riovLwMCrY3q0Cd4e0Sqp')

# %%
df14 = get_playlist_audio_features('spotify', '0h9Gaqt2sNJ8M5aMV3h9BO')

# %%
df15 = get_playlist_audio_features('spotify', '37i9dQZF1DWZiyat8YCzeB')

# %%
df17 = get_playlist_audio_features('spotify', '6Pw0qVok3XrfyER6ZvFD5V')

# %%
df18 = get_playlist_audio_features('spotify', '669fuWU8o4QEcgDPN7i0gf')

# %%
concat = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df18], axis=0)

concat
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.516   0.572    -9.037       0.0291       0.00715
# 1          0.565   0.546    -7.496       0.0314       0.18900
# 2          0.566   0.459    -9.488       0.0289       0.32700
# 3          0.537   0.128   -28.388       0.0511       0.99600
# 4          0.433   0.288   -10.801       0.0296       0.53500
# ..           ...     ...       ...          ...           ...
# 11         0.780   0.697    -8.985       0.2150       0.64600
# 12         0.525   0.472    -8.261       0.0967       0.66600
# 13         0.713   0.277   -15.459       0.5530       0.85100
# 14         0.679   0.510   -10.423       0.3860       0.86000
# 15         0.788   0.893    -5.896       0.2110       0.45800
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.254000    0.1390    0.351  160.023  22uzF19LxQW87kOVkR79Fq
# ...

# %%
concat_id = concat.drop(['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms' ], axis=1)

# %%
concat_id
# Out:
#                         id
# 0   22uzF19LxQW87kOVkR79Fq
# 1   0R8P9KfGJCDULmlEoBagcO
# 2   2w3eXFL86RgxGtDr8bzwgK
# 3   5mFtDwlHuRcsN3dpnztqDl
# 4   5TB6QgrF0RPIxSCGfRDLoe
# ..                     ...
# 11  3m9ymlEUjmWJTELUkmAPaP
# 12  4lRv3h8B7RgjvZJgqCbByd
# 13  44yJSkJP74wKO88IrHhHTY
# 14  0zlIczewzz0X36HTA1OO7l
# 15  5w8ZTpjJOfkNI0wWSsfL4o
#
# [1536 rows x 1 columns]

# %% [markdown]
# ### THURSDAY TASK

# %%
from sklearn.preprocessing import StandardScaler

# %%
concat2 = concat.drop('id', axis=1)

# %%
concat2
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.516   0.572    -9.037       0.0291       0.00715
# 1          0.565   0.546    -7.496       0.0314       0.18900
# 2          0.566   0.459    -9.488       0.0289       0.32700
# 3          0.537   0.128   -28.388       0.0511       0.99600
# 4          0.433   0.288   -10.801       0.0296       0.53500
# ..           ...     ...       ...          ...           ...
# 11         0.780   0.697    -8.985       0.2150       0.64600
# 12         0.525   0.472    -8.261       0.0967       0.66600
# 13         0.713   0.277   -15.459       0.5530       0.85100
# 14         0.679   0.510   -10.423       0.3860       0.86000
# 15         0.788   0.893    -5.896       0.2110       0.45800
#
#     instrumentalness  liveness  valence    tempo  duration_ms  cluster
# 0           0.254000    0.1390    0.351  160.023       234413        0
# 1           0.001500    0.1700    0.195  139.757       273427        0
# ...

# %%
scaler.fit(concat2)
X_scaled = scaler.transform(concat2)
X_scaled_df = pd.DataFrame(X_scaled, columns = concat2.columns)
display(concat2.head())
print()
display(X_scaled_df.head())

# %%
kmeans = KMeans(n_clusters=7, random_state=1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(n_clusters=7, random_state=1234)

# %%
kmeans.labels_

# %%
# assign a cluster to each example
labels = kmeans.predict(X_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(X.to_numpy()[row_ix, 1], X.to_numpy()[row_ix, 3])
    # show the plot
pyplot.show()

# %%
#finding the best number of clusters
from sklearn.cluster import KMeans
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
#
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
#
# Training a K-Means model with 10 clusters!
#
# Training a K-Means model with 11 clusters!
#
# Training a K-Means model with 12 clusters!
#
# Training a K-Means model with 13 clusters!
#
# Training a K-Means model with 14 clusters!
#
# Training a K-Means model with 15 clusters!
#
# Training a K-Means model with 16 clusters!
#
# Training a K-Means model with 17 clusters!
#
# Training a K-Means model with 18 clusters!
#
# Training a K-Means model with 19 clusters!
#
# Training a K-Means model with 20 clusters!
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
#silhouette method to calculate distance
import pickle
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    
    filename = "Model/kmeans_" + str(k) + ".pickle"
    with open(filename, "wb") as f:
        pickle.dump(kmeans,f)
    
    silhouette.append(silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %%
### Create clusters
clusters = kmeans.predict(X_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    212
# 1    480
# 2    163
# 3    110
# 4     25
# 5    339
# 6    207
# dtype: int64

# %%
### Adding to DF

concat2["cluster"] = clusters
concat2
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.516   0.572    -9.037       0.0291       0.00715
# 1          0.565   0.546    -7.496       0.0314       0.18900
# 2          0.566   0.459    -9.488       0.0289       0.32700
# 3          0.537   0.128   -28.388       0.0511       0.99600
# 4          0.433   0.288   -10.801       0.0296       0.53500
# ..           ...     ...       ...          ...           ...
# 11         0.780   0.697    -8.985       0.2150       0.64600
# 12         0.525   0.472    -8.261       0.0967       0.66600
# 13         0.713   0.277   -15.459       0.5530       0.85100
# 14         0.679   0.510   -10.423       0.3860       0.86000
# 15         0.788   0.893    -5.896       0.2110       0.45800
#
#     instrumentalness  liveness  valence    tempo  duration_ms  cluster
# 0           0.254000    0.1390    0.351  160.023       234413        0
# 1           0.001500    0.1700    0.195  139.757       273427        0
# ...

# %%
concat2['cluster'].unique()
# Out:
# array([0, 2, 4, 3, 6, 1, 5], dtype=int32)

# %%
# creating a new column named "concat_id" with values from concatenating columns "A" and "B"
concat2['concat_id'] = concat_id

# printing the updated dataframe
print(concat2)
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.516   0.572    -9.037       0.0291       0.00715
# 1          0.565   0.546    -7.496       0.0314       0.18900
# 2          0.566   0.459    -9.488       0.0289       0.32700
# 3          0.537   0.128   -28.388       0.0511       0.99600
# 4          0.433   0.288   -10.801       0.0296       0.53500
# ..           ...     ...       ...          ...           ...
# 11         0.780   0.697    -8.985       0.2150       0.64600
# 12         0.525   0.472    -8.261       0.0967       0.66600
# 13         0.713   0.277   -15.459       0.5530       0.85100
# 14         0.679   0.510   -10.423       0.3860       0.86000
# 15         0.788   0.893    -5.896       0.2110       0.45800
#
#     instrumentalness  liveness  valence    tempo  duration_ms  cluster  \
# 0           0.254000    0.1390    0.351  160.023       234413        0
# 1           0.001500    0.1700    0.195  139.757       273427        0
# ...

# %%
concat2
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.516   0.572    -9.037       0.0291       0.00715
# 1          0.565   0.546    -7.496       0.0314       0.18900
# 2          0.566   0.459    -9.488       0.0289       0.32700
# 3          0.537   0.128   -28.388       0.0511       0.99600
# 4          0.433   0.288   -10.801       0.0296       0.53500
# ..           ...     ...       ...          ...           ...
# 11         0.780   0.697    -8.985       0.2150       0.64600
# 12         0.525   0.472    -8.261       0.0967       0.66600
# 13         0.713   0.277   -15.459       0.5530       0.85100
# 14         0.679   0.510   -10.423       0.3860       0.86000
# 15         0.788   0.893    -5.896       0.2110       0.45800
#
#     instrumentalness  liveness  valence    tempo  duration_ms  cluster  \
# 0           0.254000    0.1390    0.351  160.023       234413        0
# 1           0.001500    0.1700    0.195  139.757       273427        0
# ...

# %%
hot_song = input("Please give the name of a song: ")
# Out:
# Please give the name of a song: Love Again

# %%
import random
import numpy as np
if hot_song in list(billboards["song"]):
    random_song = random.choice(billboards['song'])
    print("Recommended song: ", random_song, "from", np.array(billboards.loc[billboards['song']== random_song]["artist"])[0])
    
else:
    print ("Unfortunately, the song is not in the hot list!")
# Out:
# Recommended song:  La Bebe from Yng Lvcas x Peso Pluma
